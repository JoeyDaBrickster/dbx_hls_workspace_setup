# %% [markdown]
# # 01 – Discover Data
#
# **Goal:** Find the patient claims fact table in Unity Catalog and inspect its metadata, relationships, and lineage.
#
# ## Steps
# 1. Open **Catalog Explorer** (or **Data** in the sidebar).
# 2. Search for **patient claims** and open the table `fact_patient_claims` (in the workshop schema, e.g. `cms`).
# 3. Review **Metadata**: column names, types, and comments.
# 4. Review **Relationships**: foreign keys to `dim_beneficiary`, `dim_provider`, `dim_date`, `dim_diagnosis`.
# 5. Review **Lineage**: upstream sources and downstream objects.
#
# Use the cell below to run a quick query once you know your catalog and schema (set the variables or use the defaults).

# %%
-- Replace with your catalog and schema if different (instructor will provide)
USE CATALOG healthcare_dev;
USE SCHEMA cms;
DESCRIBE TABLE fact_patient_claims;

# %%
SELECT COUNT(*) AS row_count FROM fact_patient_claims;
